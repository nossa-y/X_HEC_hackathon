# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
path = "/kaggle/input/train-hi/train-data.csv"

data = pd.DataFrame(pd.read_csv(path, sep = ';'))
data.head()

# %%
max(data["Month 4"])

# %%
#transformer la date en 2 colonnes: 1 semestre, 2 annee
for date in data["Date"]:
    data["Semester"] = 1 if

# %%
data["Month 1"].unique()

# %%
# (3173346, 19)
# colonnes inutiles: -index, id_product, identificateur de maniere trop unique
# "Product Life cycel status" 432 000 non nulles => 85% des lifecycle sont nulles
# 244 857 produits differents
# seule colonne qui contient des nan: Month 1, contient 352 330 nan

# %%
data.shape

# %%
data.shape

# %%
to_drop = ["index", 'id_product', 'Product Life cycel status']
new_data = data.drop(to_drop, axis = 1)

# %%
#pour l'instant je vais drop ces lignes nan

# %%
new_data = new_data.dropna()

# %%
new_data.head(20)

# %%
#tracer table de correlation, introduire correlation temporelle

#garder 5-6 premieres caracteristiques
#entrainer le modele sur cela

# %%
#trouve un regressor qui possede une correlation matrice qui prend des objets

# %%
X = pd.DataFrame(new_data.drop("Month 4", axis = 1))
y = mydata["Month 4"]

# %%
X = new_data.drop("Month 4", axis = 1)
y = new_data["Month 4"]

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in X.columns:
    X[col] = le.fit_transform(X[col])

X.head()

# %%
y = le.transform(y.head(100))

# %%
X.head(10)

# %%
X3 = X.head(100)

# %%
for col in X.columns:
    X.

# %%
model_1_regression = LinearRegression()
model_1_regression.fit(X3, y)

# %%
import sklearn
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot
# define dataset
#X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, random_state=1)
# define the model
model = LinearRegression()
# fit the model
model.fit(X3, y)
# get importance
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
    print(data.columns[i])
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %%
#1] Site 2] Reference proxy 3] id_product 4] Zone 5] Customer Persona proxy

# %%
data["Site"].value_counts(ascending=True)

# %%
(data["Reference proxy"].value_counts(ascending=True))

# %%
data.loc[data["id_product"] >17].shape

# %%
data["Zone"].value_counts(ascending=True)

# %%
data["Reference proxy", "id_product", "Zone", "Customer Persona proxy", "Country", "Region", "Product Life Cycel status", "Date"]

# %%
data.loc[30, "Date"].split()[1]

# %%
data = data[["Reference proxy", "id_product", "Zone", "Customer Persona proxy", "Country", "Region", "Product Life cycel status", "Date"]]

# %%
#may-aug 2021
#def parse date:
#semestre
for i in data.index:
    if data.loc[i, "Date"].split()[0] == "jan-apr":
        data.loc[i, "Semester"] = 1
    elif data.loc[i, "Date"].split()[0] == "may-aug":
        data.loc[i, "Semester"] = 2
    else:
        data.loc[i, "Semester"] = 3
        
#annee
for i in data.index:
    data.loc[i, "Annee"] = data.loc[i, "Date"].split()[1]

#data = data.drop("Date")
data.head()

# %%
data.head()

# %%
from sklearn import RandomForestRegressor

X = data.drop("Month 4", axis = 1)
y = data["Month 4"]

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,random_state=0)

model = RandomForestRegressor()
model.fit(X_train, y_train)
preds = model.predict(X_valid)
mean_absolute_error(y_valid, preds)
